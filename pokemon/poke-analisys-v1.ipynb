# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset with SMART ID as the index
df = pd.read_csv('pokemondb.csv', index_col=0)
# lowercase the name of the columns
df.columns = df.columns.str.lower()
# check additional info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1025 entries, 1 to 1025
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        1025 non-null   object
#  1   type 1      1025 non-null   object
#  2   type 2      526 non-null    object
#  3   hp          1025 non-null   int64
#  4   attack      1025 non-null   int64
#  5   defense     1025 non-null   int64
#  6   sp.attack   1025 non-null   int64
#  7   sp.defense  1025 non-null   int64
#  8   speed       1025 non-null   int64
# dtypes: int64(6), object(3)
# memory usage: 80.1+ KB

# %%
# describe numerical with no decimals
pd.set_option('float_format', '{:.0f}'.format)
df.describe()
# Out:
#         hp  attack  defense  sp.attack  sp.defense  speed
# count 1025    1025     1025       1025        1025   1025
# mean    70      78       73         70          70     67
# std     27      30       29         30          27     29
# min      1       5        5         10          20      5
# 25%     50      55       50         47          50     45
# 50%     68      75       70         65          67     65
# 75%     85     100       90         90          86     88
# max    255     181      230        173         230    200

# %%
# correlation matrix
corrmat = df.corr(numeric_only=True)
f, ax = plt.subplots(figsize=(9, 9))
sns.heatmap(corrmat, vmax=1, square=True);

# %%
# scatterplot

# sns.set()
sns.set_theme()
# cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
# sns.pairplot(df, height = 2.5)
g = sns.pairplot(df, hue='type 1')

plt.show();

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >
